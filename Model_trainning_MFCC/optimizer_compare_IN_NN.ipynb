# %%
from sklearn.model_selection import train_test_split
import json
import numpy as np
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    # open the file for reading , json is actually a dictionary
    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

def plot_history(history, optimizer_name):
    """Plots accuracy/loss for training/validation set as a function of the epochs

    :param history: Training history of model
    :param optimizer_name: Name of the optimizer used
    """
    fig, axs = plt.subplots(2)  # 2 figures, subplots

    # Create accuracy subplot
    axs[0].plot(history.history["acc"], label="train accuracy")
    axs[0].plot(history.history["val_acc"], label="validation accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title(f"Accuracy Evaluation - {optimizer_name}")

    # Create error subplot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="validation error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title(f"Error Evaluation - {optimizer_name}")

    plt.tight_layout()
    plt.show()
    
def plot_compare_error(histories):
    """Plots error (loss) evaluation for training/validation set as a function of the epochs
    for multiple optimizer results.

    :param histories: Dictionary of optimizer_name: history pairs
    """
    fig, axs = plt.subplots(2)  # 2 figures, subplots
    for optimizer_name, history in histories.items():
        axs[0].plot(history.history["val_loss"], label=optimizer_name)
        axs[1].plot(history.history["loss"], label=optimizer_name)
    axs[0].set_ylabel("test error")
    axs[0].legend(loc="upper right")
    axs[0].set_title(f"test error")
    axs[1].set_ylabel("train error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title(f"train error")
    plt.tight_layout()
def plot_compare_acc(histories):
    """Plots error (loss) evaluation for training/validation set as a function of the epochs
    for multiple optimizer results.

    :param histories: Dictionary of optimizer_name: history pairs
    """
    fig, axs = plt.subplots(2)  # 2 figures, subplots
    for optimizer_name, history in histories.items():
        axs[0].plot(history.history["val_acc"], label=optimizer_name)
        axs[1].plot(history.history["acc"], label=optimizer_name)
    axs[0].set_ylabel("test accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title(f"test accuracy")
    axs[1].set_ylabel("train accuracy")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="lower right")
    axs[1].set_title(f"train accuracy")
    plt.tight_layout()

# %% [markdown]
# In this updated code, the plot_compare function now takes a histories dictionary as input, which contains the optimizer names as keys and their corresponding training histories as values. The function then plots the validation loss for each optimizer on a single plot, using a different color for each optimizer's curve. The title of the plot indicates that it's comparing optimizers.

# %%
if __name__ == "__main__":
    # Load data
    DATA_PATH = "data_10.json"
    X, y = load_data(DATA_PATH)  # X is input, y is target

    # Create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    # Define optimizers
    optimizers = {   
        'SGD': keras.optimizers.SGD(learning_rate=0.001),
        'Momentum': keras.optimizers.SGD(learning_rate=0.001),
        'RMSprop': keras.optimizers.RMSprop(learning_rate=0.0001),
        'Adam': keras.optimizers.Adam(learning_rate=0.0001),
    }
    histories = {}
    for optimizer_name, optimizer in optimizers.items():
        # Build network topology
        model = keras.Sequential([
            # Input layer
            keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),
            # 1st dense layer
            keras.layers.Dense(512, activation='relu'),
            # keras.layers.Dropout(0.3), #dropout neurons to fight overfitting, dropout probability
            # 2nd dense layer
            keras.layers.Dense(256, activation='relu'),
            # keras.layers.Dropout(0.3), #dropout neurons to fight overfitting, dropout probability
            # 3rd dense layer
            keras.layers.Dense(64, activation='relu'),
            # keras.layers.Dropout(0.3), #dropout neurons to fight overfitting, dropout probability
            # Output layer
            keras.layers.Dense(10, activation='softmax')
        ])

        # Compile model with the current optimizer
        model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        model.summary()

        # Train model
        print(f"Training model with {optimizer_name} optimizer...")
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=50)
        print(f"Finished training model with {optimizer_name} optimizer.\n")

        # Evaluate model
        test_loss, test_acc = model.evaluate(X_test, y_test)
        print(f"Test accuracy with {optimizer_name} optimizer: {test_acc}\n")

        # Plot training history
        plot_history(history, optimizer_name)

        histories[optimizer_name] = history
# Out:
# Data succesfully loaded!
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_38 (Flatten)         (None, 1690)              0
# _________________________________________________________________
# dense_152 (Dense)            (None, 512)               865792
# _________________________________________________________________
# dense_153 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_154 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_155 (Dense)            (None, 10)                650
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Training model with SGD optimizer...
# Train on 6297 samples, validate on 2699 samples
# Epoch 1/50
# 6297/6297 [==============================] - 2s 343us/sample - loss: 13.0083 - acc: 0.2876 - val_loss: 1.7965 - val_acc: 0.3690
# Epoch 2/50
# 6297/6297 [==============================] - 1s 223us/sample - loss: 1.6755 - acc: 0.4015 - val_loss: 1.7021 - val_acc: 0.3846
# Epoch 3/50
# 6297/6297 [==============================] - 2s 243us/sample - loss: 1.5014 - acc: 0.4469 - val_loss: 1.5757 - val_acc: 0.4287
# Epoch 4/50
# 6297/6297 [==============================] - 1s 228us/sample - loss: 1.3788 - acc: 0.4879 - val_loss: 1.5535 - val_acc: 0.4335
# Epoch 5/50
# 6297/6297 [==============================] - 1s 233us/sample - loss: 1.3117 - acc: 0.5171 - val_loss: 1.4918 - val_acc: 0.4757
# Epoch 6/50
# 6297/6297 [==============================] - 1s 228us/sample - loss: 1.2321 - acc: 0.5499 - val_loss: 1.4664 - val_acc: 0.4780
# Epoch 7/50
# 6297/6297 [==============================] - 1s 221us/sample - loss: 1.1822 - acc: 0.5671 - val_loss: 1.6674 - val_acc: 0.4198
# Epoch 8/50
# 6297/6297 [==============================] - 1s 224us/sample - loss: 1.1258 - acc: 0.5884 - val_loss: 1.4346 - val_acc: 0.4839
# Epoch 9/50
# 6297/6297 [==============================] - 1s 231us/sample - loss: 1.0688 - acc: 0.6160 - val_loss: 1.5096 - val_acc: 0.4794
# Epoch 10/50
# 6297/6297 [==============================] - 1s 223us/sample - loss: 1.0321 - acc: 0.6227 - val_loss: 1.3982 - val_acc: 0.5113
# Epoch 11/50
# 6297/6297 [==============================] - 1s 219us/sample - loss: 0.9925 - acc: 0.6411 - val_loss: 1.4155 - val_acc: 0.5091
# Epoch 12/50
# 6297/6297 [==============================] - 1s 231us/sample - loss: 0.9560 - acc: 0.6575 - val_loss: 1.4046 - val_acc: 0.5161
# Epoch 13/50
# 6297/6297 [==============================] - 1s 215us/sample - loss: 0
50
# 6297/6297 [==============================] - 1s 219us/sample - loss: 0.3780 - acc: 0.8779 - val_loss: 1.5505 - val_acc: 0.5669
# Epoch 37/50
# 6297/6297 [==============================] - 1s 213us/sample - loss: 0.3592 - acc: 0.8822 - val_loss: 1.5967 - val_acc: 0.5628
# Epoch 38/50
# 6297/6297 [==============================] - 1s 215us/sample - loss: 0.3471 - acc: 0.8922 - val_loss: 1.5016 - val_acc: 0.5824
# Epoch 39/50
# 6297/6297 [==============================] - 1s 228us/sample - loss: 0.3256 - acc: 0.8979 - val_loss: 1.5339 - val_acc: 0.5769
# Epoch 40/50
# 6297/6297 [==============================] - 1s 228us/sample - loss: 0.3264 - acc: 0.8933 - val_loss: 1.5478 - val_acc: 0.5876
# Epoch 41/50
# 6297/6297 [==============================] - 1s 232us/sample - loss: 0.3164 - acc: 0.9049 - val_loss: 1.5797 - val_acc: 0.5891
# Epoch 42/50
# 6297/6297 [==============================] - 1s 221us/sample - loss: 0.2900 - acc: 0.9057 - val_loss: 1.5881 - val_acc: 0.5698
# Epoch 43/50
# 6297/6297 [==============================] - 1s 219us/sample - loss: 0.2774 - acc: 0.9163 - val_loss: 1.6641 - val_acc: 0.5780
# Epoch 44/50
# 6297/6297 [==============================] - 1s 222us/sample - loss: 0.2742 - acc: 0.9141 - val_loss: 1.6996 - val_acc: 0.5721
# Epoch 45/50
# 6297/6297 [==============================] - 1s 218us/sample - loss: 0.2539 - acc: 0.9227 - val_loss: 1.6765 - val_acc: 0.5780
# Epoch 46/50
# 6297/6297 [==============================] - 1s 222us/sample - loss: 0.2445 - acc: 0.9230 - val_loss: 1.7579 - val_acc: 0.5765
# Epoch 47/50
# 6297/6297 [==============================] - 1s 230us/sample - loss: 0.2349 - acc: 0.9308 - val_loss: 1.6390 - val_acc: 0.5869
# Epoch 48/50
# 6297/6297 [==============================] - 2s 259us/sample - loss: 0.2255 - acc: 0.9336 - val_loss: 1.7056 - val_acc: 0.5932
# Epoch 49/50
# 6297/6297 [==============================] - 1s 233us/sample - loss: 0.2163 - acc: 0.9371 - val_loss: 1.7390 - val_acc: 0.5873
# Epoch 50/50
# 6297/6297 [==============================] - 1s 217us/sample - loss: 0.2213 - acc: 0.9335 - val_loss: 1.7162 - val_acc: 0.5906
# Finished training model with SGD optimizer.
#
# 2699/2699 [==============================] - 0s 96us/sample - loss: 1.7162 - acc: 0.5906
# Test accuracy with SGD optimizer: 0.5905891060829163
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_39 (Flatten)         (None, 1690)              0
# _________________________________________________________________
# dense_156 (Dense)            (None, 512)               865792
# _________________________________________________________________
# dense_157 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_158 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_159 (Dense)            (None, 10)                650
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Training model with Momentum optimizer...
# Train on 6297 samples, validate on 2699 samples
# Epoch 1/50
# 6297/6297 [==============================] - 2s 327us/sample - loss: 9.2528 - acc: 0.2881 - val_loss: 1.8984 - val_acc: 0.3231
# Epoch 2/50
# 6297/6297 [==============================] - 1s 210us/sample - loss: 1.6923 - acc: 0.3786 - val_loss: 1.8892 - val_acc: 0.3209
# Epoch 3/50
# 6297/6297 [==============================] - 1s 211us/sample - loss: 1.5780 - acc: 0.4132 - val_loss: 1.6012 - val_acc: 0.3961
# Epoch 4/50
# 6297/6297 [==============================] - 1s 214us/sample - loss: 1.4498 - acc: 0.4556 - val_loss: 1.5358 - val_acc: 0.4331
# Epoch 5/50
# 6297/6297 [==============================] - 1s 214us/sample - loss:
50
# 6297/6297 [==============================] - 1s 214us/sample - loss: 0.4931 - acc: 0.8312 - val_loss: 1.4741 - val_acc: 0.5613
# Epoch 33/50
# 6297/6297 [==============================] - 1s 214us/sample - loss: 0.4794 - acc: 0.8369 - val_loss: 1.4791 - val_acc: 0.5595
# Epoch 34/50
# 6297/6297 [==============================] - 1s 221us/sample - loss: 0.4580 - acc: 0.8469 - val_loss: 1.4559 - val_acc: 0.5658
# Epoch 35/50
# 6297/6297 [==============================] - 1s 216us/sample - loss: 0.4369 - acc: 0.8553 - val_loss: 1.5002 - val_acc: 0.5621
# Epoch 36/50
# 6297/6297 [==============================] - 1s 213us/sample - loss: 0.4240 - acc: 0.8630 - val_loss: 1.5299 - val_acc: 0.5669
# Epoch 37/50
# 6297/6297 [==============================] - 1s 217us/sample - loss: 0.3911 - acc: 0.8701 - val_loss: 1.5572 - val_acc: 0.5532
# Epoch 38/50
# 6297/6297 [==============================] - 1s 217us/sample - loss: 0.3839 - acc: 0.8742 - val_loss: 1.7199 - val_acc: 0.5235
# Epoch 39/50
# 6297/6297 [==============================] - 1s 217us/sample - loss: 0.3656 - acc: 0.8804 - val_loss: 1.4963 - val_acc: 0.5869
# Epoch 40/50
# 6297/6297 [==============================] - 1s 222us/sample - loss: 0.3521 - acc: 0.8841 - val_loss: 1.5526 - val_acc: 0.5806
# Epoch 41/50
# 6297/6297 [==============================] - 2s 262us/sample - loss: 0.3406 - acc: 0.8904 - val_loss: 1.5798 - val_acc: 0.5813
# Epoch 42/50
# 6297/6297 [==============================] - 2s 245us/sample - loss: 0.3280 - acc: 0.8930 - val_loss: 1.5842 - val_acc: 0.5687
# Epoch 43/50
# 6297/6297 [==============================] - 2s 248us/sample - loss: 0.3081 - acc: 0.9007 - val_loss: 1.5522 - val_acc: 0.5839
# Epoch 44/50
# 6297/6297 [==============================] - 1s 224us/sample - loss: 0.3040 - acc: 0.9019 - val_loss: 1.5711 - val_acc: 0.5824
# Epoch 45/50
# 6297/6297 [==============================] - 1s 222us/sample - loss: 0.2721 - acc: 0.9163 - val_loss: 1.6281 - val_acc: 0.5821
# Epoch 46/50
# 6297/6297 [==============================] - 1s 218us/sample - loss: 0.2681 - acc: 0.9195 - val_loss: 1.6820 - val_acc: 0.5695
# Epoch 47/50
# 6297/6297 [==============================] - 1s 214us/sample - loss: 0.2585 - acc: 0.9190 - val_loss: 1.8095 - val_acc: 0.5732
# Epoch 48/50
# 6297/6297 [==============================] - 1s 212us/sample - loss: 0.2450 - acc: 0.9263 - val_loss: 1.8863 - val_acc: 0.5535
# Epoch 49/50
# 6297/6297 [==============================] - 1s 227us/sample - loss: 0.2544 - acc: 0.9223 - val_loss: 1.6686 - val_acc: 0.5850
# Epoch 50/50
# 6297/6297 [==============================] - 1s 230us/sample - loss: 0.2189 - acc: 0.9296 - val_loss: 1.6995 - val_acc: 0.5791
# Finished training model with Momentum optimizer.
#
# 2699/2699 [==============================] - 0s 132us/sample - loss: 1.6995 - acc: 0.5791
# Test accuracy with Momentum optimizer: 0.5791033506393433
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_40 (Flatten)         (None, 1690)              0
# _________________________________________________________________
# dense_160 (Dense)            (None, 512)               865792
# _________________________________________________________________
# dense_161 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_162 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_163 (Dense)            (None, 10)                650
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Training model with RMSprop optimizer...
# Train on 6297 samples, validate on 2699 samples
# Epoch 1/50
# 6297/6297 [==============================] - 3s 521us/sample - loss: 5.5489 - acc: 0.2714 - val_loss: 2.0501 - val_acc: 0.2838
# Epoch 2/50
# 6297/6297 [==============================] - 3s 472us/sample - loss: 1.9319 - acc: 0.3236 - val_loss: 1.9607 - val_acc: 0.3320
# Epoch 3/50
# 6297/6297 [==============================] - 3s 398us/sample - loss: 1.7717 - acc: 0.3784 - val_loss: 1.9010 - val_acc: 0.3727
# Epoch 4/50
# 6297/6297 [==============================] - 2s 371us/sample - loss: 1.6605 - acc: 0.4146 - val_loss: 2.0047 - val_acc: 0.3564
# Epoch 5/50
# 6297/6297 [==============================] - 2s 359us/sample - loss: 1.5699 - acc: 0.4448 - val_loss: 1.9097 - val_acc: 0.4001
# Epoch 6/50
# 6297/6297 [==============================] - 2s 364us/sample - loss: 1.4798 - acc: 0.4726 - val_loss: 1.8552 - val_acc: 0.4179
# Epoch 7/50
# 6297/6297 [==============================] - 3s 401us/sample - loss: 1.4176 - acc: 0.4945 - val_loss: 1.7556 - val_acc: 0.4416
# Epoch 8/50
# 6297/6297 [==============================] - 2s 362us/sample - loss: 1.3501 - acc: 0.5188 - val_loss: 2.1622 - val_acc: 0.3938
# Epoch 9/50
# 6297/6297 [==============================] - 2s 359us/sample - loss: 1.2999 - acc: 0.5179 - val_loss: 1.9779 - val_acc: 0.4431
# Epoch 10/50
# 6297/6297 [==============================] - 2s 359us/sample - loss: 1.2361 - acc: 0.5442 - val_loss: 1.7731 - val_acc: 0.4680
# Epoch 11/50
# 6297/6297 [==============================] - 2s 352us/sample - loss: 1.1915 - acc: 0.5584 - val_loss: 1.7012 - val_acc: 0.4709
# Epoch 12/50
# 6297/6297 [==============================] - 2s 352us/sample - loss: 1.1406 - acc: 0.5755 - val_loss: 1.7033 - val_acc: 0.4594
# Epoch 13/50
# 6297/6297 [==============================] - 2s 352us/sample - loss: 1.0661 - acc: 0.5973 - val_loss: 1.8424 - val_acc: 0.4980
# Epoch 14/50
# 6297/6297 [==============================] - 2s 364us/sample - loss: 1.0305 - acc: 0.6114 - val_loss: 1.8746 - val_acc: 0.4983
# Epoch 15/50
# 6297/6297 [==============================] - 2s 354us/sample - loss: 1.0014 - acc: 0.6328 - val_loss: 1.7014 - val_acc: 0.5361
# Epoch 16/50
# 6297/6297 [==============================] - 2s 356us/sample - loss: 0.9512 - acc: 0.6557 - val_loss: 1.8524 - val_acc: 0.5358
# Epoch 17/50
# 6297/6297 [==============================] - 2s 355us/sample - loss: 0.8957 - acc: 0.6643 - val_loss: 1.6887 - val_acc: 0.5124
# Epoch 18/50
# 6297/6297 [==============================] - 2s 348us/sample - loss: 0.8720 - acc: 0.6725 - val_loss: 1.8823 - val_acc: 0.5613
# Epoch 19/50
50
# 6297/6297 [==============================] - 2s 351us/sample - loss: 0.3919 - acc: 0.8618 - val_loss: 2.4449 - val_acc: 0.5973
# Epoch 41/50
# 6297/6297 [==============================] - 2s 348us/sample - loss: 0.3638 - acc: 0.8704 - val_loss: 3.0070 - val_acc: 0.5584
# Epoch 42/50
# 6297/6297 [==============================] - 2s 350us/sample - loss: 0.3722 - acc: 0.8722 - val_loss: 2.2927 - val_acc: 0.6250
# Epoch 43/50
# 6297/6297 [==============================] - 2s 351us/sample - loss: 0.3436 - acc: 0.8772 - val_loss: 2.5843 - val_acc: 0.6099
# Epoch 44/50
# 6297/6297 [==============================] - 2s 349us/sample - loss: 0.3494 - acc: 0.8788 - val_loss: 2.6206 - val_acc: 0.6010
# Epoch 45/50
# 6297/6297 [==============================] - 2s 350us/sample - loss: 0.3354 - acc: 0.8831 - val_loss: 2.7321 - val_acc: 0.5876
# Epoch 46/50
# 6297/6297 [==============================] - 2s 349us/sample - loss: 0.3356 - acc: 0.8882 - val_loss: 3.1631 - val_acc: 0.5598
# Epoch 47/50
# 6297/6297 [==============================] - 2s 354us/sample - loss: 0.3163 - acc: 0.8936 - val_loss: 2.7360 - val_acc: 0.6139
# Epoch 48/50
# 6297/6297 [==============================] - 2s 354us/sample - loss: 0.3039 - acc: 0.8953 - val_loss: 2.6771 - val_acc: 0.6213
# Epoch 49/50
# 6297/6297 [==============================] - 2s 351us/sample - loss: 0.2887 - acc: 0.8987 - val_loss: 2.7351 - val_acc: 0.6080
# Epoch 50/50
# 6297/6297 [==============================] - 2s 358us/sample - loss: 0.2934 - acc: 0.9022 - val_loss: 2.8902 - val_acc: 0.6225
# Finished training model with RMSprop optimizer.
#
# 2699/2699 [==============================] - 0s 104us/sample - loss: 2.8902 - acc: 0.6225
# Test accuracy with RMSprop optimizer: 0.6224527359008789
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_41 (Flatten)         (None, 1690)              0
# _________________________________________________________________
# dense_164 (Dense)            (None, 512)               865792
# _________________________________________________________________
# dense_165 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_166 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_167 (Dense)            (None, 10)                650
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Training model with Adam optimizer...
# Train on 6297 samples, validate on 2699 samples
# Epoch 1/50
# 6297/6297 [==============================] - 2s 373us/sample - loss: 6.6592 - acc: 0.3392 - val_loss: 2.8345 - val_acc: 0.3790
# Epoch 2/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 2.0713 - acc: 0.3961 - val_loss: 1.9063 - val_acc: 0.3809
# Epoch 3/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 1.6120 - acc: 0.4726 - val_loss: 1.7988 - val_acc: 0.4435
# Epoch 4/50
# 6297/6297 [==============================] - 2s 252us/sample - loss: 1.4470 - acc: 0.5144 - val_loss: 1.8349 - val_acc: 0.4342
# Epoch 5/50
# 6297/6297 [==============================] - 2s 256us/sample - loss: 1.3012 - acc: 0.5514 - val_loss: 1.7482 - val_acc: 0.4691
# Epoch 6/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 1.1752 - acc: 0.5865 - val_loss: 1.6709 - val_acc: 0.4813
# Epoch 7/50
# 6297/6297 [==============================] - 2s 253us/sample - loss: 1.0815 - acc: 0.6230 - val_loss: 1.6265 - val_acc: 0.4913
# Epoch 8/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.9888 - acc: 0.6513 - val_loss: 1.6927 - val_acc: 0.5006
# Epoch 9/50
# 6297/6297 [==============================] - 2s 252us/sample - loss: 0.8904 - acc: 0.6867 - val_loss: 1.5932 - val_acc: 0.5258
# Epoch 10/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.8275 - acc: 0.7084 - val_loss: 1.7886 - val_acc: 0.4969
# Epoch 11/50
# 6297/6297 [==============================] - 2s 253us/sample - loss: 0.7433 - acc: 0.7367 - val_loss: 1.6462 - val_acc: 0.5380
# Epoch 12/50
# 6297/6297 [==============================] - 2s 252us/sample - loss: 0.6964 - acc: 0.7504 - val_loss: 1.5886 - val_acc: 0.5550
# Epoch 13/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.6512 - acc: 0.7650 - val_loss: 1.6566 - val_acc: 0.5432
# Epoch 14/50
# 6297/6297 [==============================] - 2s 253us/sample - loss: 0.5915 - acc: 0.7886 - val_loss: 1.6099 - val_acc: 0.5591
# Epoch 15/50
# 6297/6297 [==============================] - 2s 260us/sample - loss: 0.5218 - acc: 0.8136 - val_loss: 1.6635 - val_acc: 0.5624
# Epoch 16/50
# 6297/6297 [==============================] - 2s 257us/sample - loss: 0.5146 - acc: 0.8207 - val_loss: 1.6468 - val_acc: 0.5569
# Epoch 17/50
# 6297/6297 [==============================] - 2s 256us/sample - loss: 0.4718 - acc: 0.8272 - val_loss: 1.6980 - val_acc: 0.5835
# Epoch 18/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 0.4313 - acc: 0.8466 - val_loss: 1.7601 - val_acc: 0.5669
# Epoch 19/50
# 6297/6297 [==============================] - 2s 256us/sample - loss: 0.3941 - acc: 0.8593 - val_loss: 1.8299 - val_acc: 0.5672
# Epoch 20/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.3469 - acc: 0.8720 - val_loss: 1.9908 - val_acc: 0.5747
# Epoch 21/50
# 6297/6297 [==============================] - 2s 257us/sample - loss: 0.3356 - acc: 0.8798 - val_loss: 1.7781 - val_acc: 0.5965
# Epoch 22/50
# 6297/6297 [==============================] - 2s 252us/sample - loss: 0.3014 - acc: 0.8917 - val_loss: 1.8291 - val_acc: 0.5828
# Epoch 23/50
# 6297/6297 [==============================] - 2s 258us/sample - loss: 0.3284 - acc: 0.8842 - val_loss: 1.7901 - val_acc: 0.5969
# Epoch 24/50
# 6297/6297 [==============================] - 2s 257us/sample - loss: 0.2296 - acc: 0.9230 - val_loss: 1.8883 - val_acc: 0.5976
# Epoch 25/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.2630 - acc: 0.9081 - val_loss: 1.8794 - val_acc: 0.5928
# Epoch 26/50
# 6297/6297 [==============================] - 2s 258us/sample - loss: 0.2655 - acc: 0.9098 - val_loss: 1.8710 - val_acc: 0.5850
# Epoch 27/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.2458 - acc: 0.9168 - val_loss: 1.9012 - val_acc: 0.5891
# Epoch 28/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 0.2340 - acc: 0.9168 - val_loss: 1.8752 - val_acc: 0.5928
# Epoch 29/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 0.2153 - acc: 0.9247 - val_loss: 1.9569 - val_acc: 0.5906
# Epoch 30/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.1797 - acc: 0.9370 - val_loss: 2.4134 - val_acc: 0.5784
# Epoch 31/50
# 6297/6297 [==============================] - 2s 261us/sample - loss: 0.2424 - acc: 0.9173 - val_loss: 2.0679 - val_acc: 0.6002
# Epoch 32/50
# 6297/6297 [==============================] - 2s 260us/sample - loss: 0.1689 - acc: 0.9404 - val_loss: 2.0032 - val_acc: 0.6006
# Epoch 33/50
# 6297/6297 [==============================] - 2s 256us/sample - loss: 0.1853 - acc: 0.9373 - val_loss: 2.1980 - val_acc: 0.6084
# Epoch 34/50
# 6297/6297 [==============================] - 2s 258us/sample - loss: 0.1778 - acc: 0.9401 - val_loss: 2.0775 - val_acc: 0.6047
# Epoch 35/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.1397 - acc: 0.9524 - val_loss: 2.1792 - val_acc: 0.6006
# Epoch 36/50
# 6297/6297 [==============================] - 2s 257us/sample - loss: 0.1546 - acc: 0.9478 - val_loss: 2.1132 - val_acc: 0.6039
# Epoch 37/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.1056 - acc: 0.9657 - val_loss: 2.2541 - val_acc: 0.5924
# Epoch 38/50
# 6297/6297 [==============================] - 2s 259us/sample - loss: 0.1597 - acc: 0.9435 - val_loss: 2.1999 - val_acc: 0.6095
# Epoch 39/50
# 6297/6297 [==============================] - 2s 253us/sample - loss: 0.1589 - acc: 0.9481 - val_loss: 2.1582 - val_acc: 0.6124
# Epoch 40/50
# 6297/6297 [==============================] - 2s 252us/sample - loss: 0.1356 - acc: 0.9527 - val_loss: 2.4756 - val_acc: 0.5984
# Epoch 41/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 0.0961 - acc: 0.9700 - val_loss: 2.1330 - val_acc: 0.6158
# Epoch 42/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 0.0755 - acc: 0.9757 - val_loss: 2.2151 - val_acc: 0.6328
# Epoch 43/50
# 6297/6297 [==============================] - 2s 257us/sample - loss: 0.1919 - acc: 0.9349 - val_loss: 2.5050 - val_acc: 0.5976
# Epoch 44/50
# 6297/6297 [==============================] - 2s 255us/sample - loss: 0.1937 - acc: 0.9350 - val_loss: 2.2592 - val_acc: 0.5969
# Epoch 45/50
# 6297/6297 [==============================] - 2s 254us/sample - loss: 0.1176 - acc: 0.9630 - val_loss: 2.3415 - val_acc: 0.6087
# Epoch 46/50
# 6297/6297 [==============================] - 2s 256us/sample - loss: 0.0861 - acc: 0.9716 - val_loss: 2.3480 - val_acc: 0.6173
# Epoch 47/50
# 6297/6297 [==============================] - 2s 256us/sample - loss: 0.1059 - acc: 0.9682 - val_loss: 2.3340 - val_acc: 0.6299
# Epoch 48/50
# 6297/6297 [==============================] - 2s 260us/sample - loss: 0.0516 - acc: 0.9851 - val_loss: 2.2478 - val_acc: 0.6365
# Epoch 49/50
# 6297/6297 [==============================] - 2s 258us/sample - loss: 0.0957 - acc: 0.9708 - val_loss: 2.5989 - val_acc: 0.5969
# Epoch 50/50
# 6297/6297 [==============================] - 2s 253us/sample - loss: 0.2268 - acc: 0.9258 - val_loss: 2.3302 - val_acc: 0.6258
# Finished training model with Adam optimizer.
#
# 2699/2699 [==============================] - 0s 101us/sample - loss: 2.3302 - acc: 0.6258
# Test accuracy with Adam optimizer: 0.6257873177528381

# %%
plot_compare_error(histories)
plot_compare_acc(histories)
